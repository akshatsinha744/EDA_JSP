          0.0008, 0.0007, 0.0006, 0.0007, 0.0008, 0.0009, 0.0007, 0.0008, 0.0008, 0.0008,
          0.0008, 0.0007, 0.0009, 0.0009, 0.0007, 0.0008, 0.0009, 0.0008, 0.0009, 0.0009],
    'DF': [5.56, 0.46, 0.49, 0.78, 1.41, 0.37, 0.42, 0.27, 0.33, 1.01,
           0.23, 1.22, 0.83, 1.50, 0.20, 1.56, 0.46, 1.36, 0.31, 0.24,
           0.25, 0.44, 0.35, 0.24, 1.51, 0.22, 0.24, 0.45, 0.43, 1.46]
}

# Creating a DataFrame
df = pd.DataFrame(data)

# Reference sample values
ref_values = {
    'C': 0.60,
    'Si': 2.00,
    'Mn': 0.85,
    'P': 0.020,
    'S': 0.015,
    'Cr': 0.0,
    'Mo': 0.0,
    'Sn': 0.001,
    'Sb': 0.005,
    'O': 0.0010
}

# Calculate differences from reference
for col in ref_values.keys():
    df[col + '_diff'] = df[col] - ref_values[col]

# Visualization
plt.figure(figsize=(14, 10))

# Histograms of chemical components
for i, col in enumerate(ref_values.keys()):
    plt.subplot(3, 4, i + 1)
    plt.hist(df[col], bins=10, alpha=0.75, label='Sample')
    plt.axvline(ref_values[col], color='r', linestyle='dashed', linewidth=1, label='Reference')
    plt.title(col)
    plt.legend()

plt.tight_layout()
plt.show()

# Bar plot of DF
plt.figure(figsize=(10, 6))
plt.bar(df['SNo.'], df['DF'], color='b', alpha=0.6, label='DF Value')
plt.axhline(df['DF'].mean(), color='r', linestyle='dashed', linewidth=1, label='Mean DF')
plt.xlabel('Sample Number')
plt.ylabel('DF Value')
plt.title('DF Value of Steel Samples')
plt.legend()
plt.xticks(df['SNo.'])
plt.grid(True)
plt.show()

# Scatter plots of chemical components vs DF
plt.figure(figsize=(14, 10))
for i, col in enumerate(ref_values.keys()):
    plt.subplot(3, 4, i + 1)
    plt.scatter(df[col], df['DF'], alpha=0.6)
    plt.xlabel(col)
    plt.ylabel('DF Value')
    plt.title(f'{col} vs DF')

plt.tight_layout()
plt.show()

# Summary statistics
summary_stats = df.describe()
print(summary_stats)
# Out:
#             SNo.          C         Si         Mn          P          S  \
# count  30.000000  30.000000  30.000000  30.000000  30.000000  30.000000
# mean   15.500000   0.413000   2.031000   0.634667   0.006767   0.004600
# std     8.803408   0.043243   0.209784   0.278106   0.002812   0.002486
# min     1.000000   0.350000   1.750000   0.210000   0.004000   0.001000
# 25%     8.250000   0.390000   1.900000   0.365000   0.005000   0.003000
# 50%    15.500000   0.410000   2.000000   0.650000   0.006000   0.004000
# 75%    22.750000   0.420000   2.215000   0.890000   0.007000   0.005000
# max    30.000000   0.600000   2.400000   0.990000   0.020000   0.015000
#
#               Cr         Mo         Sn         Sb  ...     C_diff    Si_diff  \
# count  30.000000  30.000000  30.000000  30.000000  ...  30.000000  30.000000
# mean    0.261333   0.255667   0.058367   0.048333  ...  -0.187000   0.031000
# std     0.180893   0.244846   0.075728   0.041792  ...   0.043243   0.209784
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

#
           0.35, 0.45, 0.46, 0.35, 0.42, 0.35, 0.42, 0.41, 0.39, 0.30,
           0.21, 0.89, 0.89, 0.89, 0.35, 0.37, 0.33, 0.47, 0.43, 0.38]
}

# Creating a DataFrame for WD
df_wd = pd.DataFrame(wd_data)

# Visualization for WD
plt.figure(figsize=(10, 6))
plt.bar(df_wd['SNo.'], df_wd['WD'], color='m', alpha=0.6, label='WD Value')
plt.axhline(df_wd['WD'].mean(), color='r', linestyle='dashed', linewidth=1, label='Mean WD')
plt.xlabel('Sample Number')
plt.ylabel('WD Value')
plt.title('WD Value of Steel Samples')
plt.legend()
plt.xticks(df_wd['SNo.'])
plt.grid(True)
plt.tight_layout()
plt.show()

# Scatter plot of chemical components vs WD
plt.figure(figsize=(14, 10))
for i, col in enumerate(ref_values.keys()):
    plt.subplot(3, 4, i + 1)
    plt.scatter(df[col], df_wd['WD'], alpha=0.6)
    plt.xlabel(col)
    plt.ylabel('WD Value')
    plt.title(f'{col} vs WD')

plt.tight_layout()
plt.show()

# Summary statistics for WD
summary_stats_wd = df_wd['WD'].describe()
print(summary_stats_wd)
# Out:
# count    30.000000
# mean      0.435667
# std       0.168925
# min       0.210000
# 25%       0.350000
# 50%       0.390000
# 75%       0.445000
# max       0.890000
# Name: WD, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data provided for DT values
dt_data = {
    'SNo.': list(range(1, 31)),
        'C': [0.60, 0.42, 0.38, 0.44, 0.39, 0.42, 0.41, 0.39, 0.42, 0.39, 
          0.37, 0.42, 0.41, 0.42, 0.39, 0.41, 0.42, 0.42, 0.36, 0.41, 
          0.38, 0.44, 0.44, 0.44, 0.41, 0.37, 0.40, 0.43, 0.44, 0.35],
    'Si': [2.00, 2.01, 1.76, 1.91, 1.98, 1.90, 2.22, 1.94, 2.39, 2.28,
           2.01, 1.85, 1.76, 2.40, 1.75, 2.30, 1.95, 2.05, 2.00, 2.00, 
           2.40, 1.75, 2.00, 2.20, 2.29, 1.90, 2.33, 1.76, 2.00, 1.84],
    'Mn': [0.85, 0.88, 0.85, 0.21, 0.30, 0.41, 0.77, 0.65, 0.50, 0.95,
           0.35, 0.65, 0.54, 0.41, 0.21, 0.35, 0.25, 0.45, 0.63, 0.95, 
           0.99, 0.89, 0.89, 0.89, 0.33, 0.21, 0.99, 0.89, 0.89, 0.91],
    'P': [0.020, 0.005, 0.006, 0.007, 0.009, 0.008, 0.006, 0.008, 0.007, 0.008,
          0.007, 0.008, 0.007, 0.006, 0.005, 0.007, 0.005, 0.005, 0.004, 0.006,
          0.005, 0.004, 0.006, 0.006, 0.006, 0.008, 0.005, 0.007, 0.007, 0.005],
    'S': [0.015, 0.006, 0.005, 0.007, 0.005, 0.004, 0.005, 0.004, 0.006, 0.006,
          0.007, 0.007, 0.005, 0.005, 0.004, 0.003, 0.002, 0.003, 0.002, 0.004,
          0.003, 0.004, 0.003, 0.004, 0.003, 0.003, 0.003, 0.005, 0.004, 0.001],
    'Cr': [0.0, 0.04, 0.04, 0.03, 0.49, 0.49, 0.21, 0.45, 0.48, 0.35,
           0.33, 0.15, 0.22, 0.49, 0.25, 0.48, 0.48, 0.40, 0.25, 0.11,
           0.45, 0.21, 0.05, 0.05, 0.47, 0.11, 0.45, 0.21, 0.05, 0.05],
    'Mo': [0.0, 0.20, 0.18, 0.11, 0.05, 0.25, 0.20, 0.18, 0.15, 0.10,
           0.17, 0.15, 0.11, 0.05, 0.15, 0.20, 0.92, 0.35, 0.21, 0.20,
           0.12, 0.44, 0.92, 0.92, 0.15, 0.21, 0.12, 0.44, 0.21, 0.21],
    'Sn': [0.001, 0.005, 0.005, 0.005, 0.001, 0.001, 0.050, 0.150, 0.111, 0.018,
           0.200, 0.001, 0.001, 0.001, 0.110, 0.001, 0.100, 0.035, 0.180, 0.200,
           0.001, 0.001, 0.210, 0.001, 0.115, 0.190, 0.001, 0.020, 0.001, 0.035],
    'Sb': [0.005, 0.100, 0.090, 0.051, 0.035, 0.120, 0.080, 0.035, 0.062, 0.040,
           0.035, 0.035, 0.051, 0.037, 0.120, 0.035, 0.002, 0.001, 0.002, 0.002,
           0.050, 0.090, 0.130, 0.002, 0.036, 0.115, 0.002, 0.085, 0.001, 0.001],
    'O': [0.0010, 0.0009, 0.0008, 0.0007, 0.0008, 0.0006, 0.0007, 0.0008, 0.0006, 0.0007,
          0.0008, 0.0007, 0.0006, 0.0007, 0.0008, 0.0009, 0.0007, 0.0008, 0.0008, 0.0008,
          0.0008, 0.0007, 0.0009, 0.0009, 0.0007, 0.0008, 0.0009, 0.0008, 0.0009, 0.0009],
    'DT': [333, 245, 222, 250, 220, 247, 242, 238, 253, 223,
           233, 237, 243, 231, 245, 237, 221, 251, 240, 254,
           259, 269, 232, 232, 250, 249, 256, 298, 250, 231]
}

# Creating a DataFrame for DT
df_dt = pd.DataFrame(dt_data)

# Visualization for DT
plt.figure(figsize=(10, 6))
plt.bar(df_dt['SNo.'], df_dt['DT'], color='g', alpha=0.6, label='DT Value')
plt.axhline(df_dt['DT'].mean(), color='r', linestyle='dashed', linewidth=1, label='Mean DT')
plt.xlabel('Sample Number')
plt.ylabel('DT Value')
plt.title('DT Value of Steel Samples')
plt.legend()
plt.xticks(df_dt['SNo.'])
plt.grid(True)
plt.tight_layout()
plt.show()

# Scatter plot of chemical components vs DT
plt.figure(figsize=(14, 10))
for i, col in enumerate(ref_values.keys()):
    plt.subplot(3, 4, i + 1)
    plt.scatter(df[col], df_dt['DT'], alpha=0.6)
    plt.xlabel(col)
    plt.ylabel('DT Value')
    plt.title(f'{col} vs DT')

plt.tight_layout()
plt.show()

# Summary statistics for DT
summary_stats_dt = df_dt['DT'].describe()
print(summary_stats_dt)
# Out:
# count     30.000000
# mean     246.366667
# std       22.719403
# min      220.000000
# 25%      232.250000
# 50%      244.000000
# 75%      250.750000
# max      333.000000
# Name: DT, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data provided
data = {
    'SNo.': list(range(1, 31)),
    'C': [0.60, 0.42, 0.38, 0.44, 0.39, 0.42, 0.41, 0.39, 0.42, 0.39, 
          0.37, 0.42, 0.41, 0.42, 0.39, 0.41, 0.42, 0.42, 0.36, 0.41, 
          0.38, 0.44, 0.44, 0.44, 0.41, 0.37, 0.40, 0.43, 0.44, 0.35],
           0.25, 0.44, 0.35, 0.24, 1.51, 0.22, 0.24, 0.45, 0.43, 1.46],
    'DT': [333, 245, 222, 250, 220, 247, 242, 238, 253, 223,
           233, 237, 243, 231, 245, 237, 221, 251, 240, 254,
           259, 269, 232, 232, 250, 249, 256, 298, 250, 231],
    'WD': [0.60, 0.41, 0.42, 0.45, 0.39, 0.36, 0.27, 0.39, 0.33, 0.34,
           0.35, 0.45, 0.46, 0.35, 0.42, 0.35, 0.42, 0.41, 0.39, 0.30,
           0.21, 0.89, 0.89, 0.89, 0.35, 0.37, 0.33, 0.47, 0.43, 0.38]
}

# Creating DataFrames for DF, DT, and WD
df = pd.DataFrame(data)

# Visualization for DF
plt.figure(figsize=(10, 6))
plt.bar(df['SNo.'], df['DF'], color='b', alpha=0.6, label='DF Value')
plt.axhline(df['DF'].mean(), color='r', linestyle='dashed', linewidth=1, label='Mean DF')
plt.xlabel('Sample Number')
plt.ylabel('DF Value')
plt.title('DF Value of Steel Samples')
plt.legend()
plt.xticks(df['SNo.'])
plt.grid(True)
plt.tight_layout()

# Visualization for DT
plt.figure(figsize=(10, 6))
plt.bar(df['SNo.'], df['DT'], color='g', alpha=0.6, label='DT Value')
plt.axhline(df['DT'].mean(), color='r', linestyle='dashed', linewidth=1, label='Mean DT')
plt.xlabel('Sample Number')
plt.ylabel('DT Value')
plt.title('DT Value of Steel Samples')
plt.legend()
plt.xticks(df['SNo.'])
plt.grid(True)
plt.tight_layout()

# Visualization for WD
plt.figure(figsize=(10, 6))
plt.bar(df['SNo.'], df['WD'], color='m', alpha=0.6, label='WD Value')
plt.axhline(df['WD'].mean(), color='r', linestyle='dashed', linewidth=1, label='Mean WD')
plt.xlabel('Sample Number')
plt.ylabel('WD Value')
plt.title('WD Value of Steel Samples')
plt.legend()
plt.xticks(df['SNo.'])
plt.grid(True)
plt.tight_layout()

# Scatter plot of chemical components vs DF
plt.figure(figsize=(14, 10))
for i, col in enumerate(['C', 'Si', 'Mn', 'P', 'S', 'Cr', 'Mo', 'Sn', 'Sb', 'O']):
    plt.subplot(4, 3, i + 1)
    plt.scatter(df[col], df['DF'], alpha=0.6)
    plt.xlabel(col)
    plt.ylabel('DF Value')
    plt.title(f'{col} vs DF')

plt.tight_layout()

# Scatter plot of chemical components vs DT
plt.figure(figsize=(14, 10))
for i, col in enumerate(['C', 'Si', 'Mn', 'P', 'S', 'Cr', 'Mo', 'Sn', 'Sb', 'O']):
    plt.subplot(4, 3, i + 1)
    plt.scatter(df[col], df['DT'], alpha=0.6)
    plt.xlabel(col)
    plt.ylabel('DT Value')
    plt.title(f'{col} vs DT')

plt.tight_layout()

# Scatter plot of chemical components vs WD
plt.figure(figsize=(14, 10))
for i, col in enumerate(['C', 'Si', 'Mn', 'P', 'S', 'Cr', 'Mo', 'Sn', 'Sb', 'O']):
    plt.subplot(4, 3, i + 1)
    plt.scatter(df[col], df['WD'], alpha=0.6)
    plt.xlabel(col)
    plt.ylabel('WD Value')
    plt.title(f'{col} vs WD')

plt.tight_layout()

# Summary statistics for DF, DT, and WD
summary_stats_df = df['DF'].describe()
summary_stats_dt = df['DT'].describe()
summary_stats_wd = df['WD'].describe()

print("\nSummary Statistics for DF:")
print(summary_stats_df)

print("\nSummary Statistics for DT:")
print(summary_stats_dt)

print("\nSummary Statistics for WD:")
print(summary_stats_wd)

plt.show()
# Out:
# Summary Statistics for DF:
# count    30.000000
# mean      0.820000
# std       1.013954
# min       0.200000
# 25%       0.280000
# 50%       0.445000
# 75%       1.167500
# max       5.560000
# Name: DF, dtype: float64
#
# Summary Statistics for DT:
# count     30.000000
# mean     246.366667
# std       22.719403
# min      220.000000
# 25%      232.250000
# 50%      244.000000
# 75%      250.750000
# max      333.000000
# Name: DT, dtype: float64
#
# Summary Statistics for WD:
# count    30.000000
# mean      0.435667
# std       0.168925
# min       0.210000
# 25%       0.350000
# 50%       0.390000
# 75%       0.445000
# max       0.890000
# Name: WD, dtype: float64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Data provided
data = {
    'SNo.': list(range(1, 31)),
    'C': [0.60, 0.42, 0.38, 0.44, 0.39, 0.42, 0.41, 0.39, 0.42, 0.39, 
          0.37, 0.42, 0.41, 0.42, 0.39, 0.41, 0.42, 0.42, 0.36, 0.41, 
          0.38, 0.44, 0.44, 0.44, 0.41, 0.37, 0.40, 0.43, 0.44, 0.35],
    'Si': [2.00, 2.01, 1.76, 1.91, 1.98, 1.90, 2.22, 1.94, 2.39, 2.28,
           2.01, 1.85, 1.76, 2.40, 1.75, 2.30, 1.95, 2.05, 2.00, 2.00, 
           2.40, 1.75, 2.00, 2.20, 2.29, 1.90, 2.33, 1.76, 2.00, 1.84],
    'Mn': [0.85, 0.88, 0.85, 0.21, 0.30, 0.41, 0.77, 0.65, 0.50, 0.95,
           0.35, 0.65, 0.54, 0.41, 0.21, 0.35, 0.25, 0.45, 0.63, 0.95, 
           0.99, 0.89, 0.89, 0.89, 0.33, 0.21, 0.99, 0.89, 0.89, 0.91],
    'P': [0.020, 0.005, 0.006, 0.007, 0.009, 0.008, 0.006, 0.008, 0.007, 0.008,
          0.007, 0.008, 0.007, 0.006, 0.005, 0.007, 0.005, 0.005, 0.004, 0.006,
          0.005, 0.004, 0.006, 0.006, 0.006, 0.008, 0.005, 0.007, 0.007, 0.005],
    'S': [0.015, 0.006, 0.005, 0.007, 0.005, 0.004, 0.005, 0.004, 0.006, 0.006,
          0.007, 0.007, 0.005, 0.005, 0.004, 0.003, 0.002, 0.003, 0.002, 0.004,
          0.003, 0.004, 0.003, 0.004, 0.003, 0.003, 0.003, 0.005, 0.004, 0.001],
    'Cr': [0.0, 0.04, 0.04, 0.03, 0.49, 0.49, 0.21, 0.45, 0.48, 0.35,
           0.33, 0.15, 0.22, 0.49, 0.25, 0.48, 0.48, 0.40, 0.25, 0.11,
           0.45, 0.21, 0.05, 0.05, 0.47, 0.11, 0.45, 0.21, 0.05, 0.05],
    'Mo': [0.0, 0.20, 0.18, 0.11, 0.05, 0.25, 0.20, 0.18, 0.15, 0.10,
           0.17, 0.15, 0.11, 0.05, 0.15, 0.20, 0.92, 0.35, 0.21, 0.20,
           0.12, 0.44, 0.92, 0.92, 0.15, 0.21, 0.12, 0.44, 0.21, 0.21],
    'Sn': [0.001, 0.005, 0.005, 0.005, 0.001, 0.001, 0.050, 0.150, 0.111, 0.018,
           0.200, 0.001, 0.001, 0.001, 0.110, 0.001, 0.100, 0.035, 0.180, 0.200,
           0.001, 0.001, 0.210, 0.001, 0.115, 0.190, 0.001, 0.020, 0.001, 0.035],
    'Sb': [0.005, 0.100, 0.090, 0.051, 0.035, 0.120, 0.080, 0.035, 0.062, 0.040,
           0.035, 0.035, 0.051, 0.037, 0.120, 0.035, 0.002, 0.001, 0.002, 0.002,
           0.050, 0.090, 0.130, 0.002, 0.036, 0.115, 0.002, 0.085, 0.001, 0.001],
    'O': [0.0010, 0.0009, 0.0008, 0.0007, 0.0008, 0.0006, 0.0007, 0.0008, 0.0006, 0.0007,
          0.0008, 0.0007, 0.0006, 0.0007, 0.0008, 0.0009, 0.0007, 0.0008, 0.0008, 0.0008,
          0.0008, 0.0007, 0.0009, 0.0009, 0.0007, 0.0008, 0.0009, 0.0008, 0.0009, 0.0009],
    'DF': [5.56, 0.46, 0.49, 0.78, 1.41, 0.37, 0.42, 0.27, 0.33, 1.01,
           0.23, 1.22, 0.83, 1.50, 0.20, 1.56, 0.46, 1.36, 0.31, 0.24,
           0.25, 0.44, 0.35, 0.24, 1.51, 0.22, 0.24, 0.45, 0.43, 1.46],
    'DT': [333, 245, 222, 250, 220, 247, 242, 238, 253, 223,
           233, 237, 243, 231, 245, 237, 221, 251, 240, 254,
           259, 269, 232, 232, 250, 249, 256, 298, 250, 231],
    'WD': [0.60, 0.41, 0.42, 0.45, 0.39, 0.36, 0.27, 0.39, 0.33, 0.34,
           0.35, 0.45, 0.46, 0.35, 0.42, 0.35, 0.42, 0.41, 0.39, 0.30,
           0.21, 0.89, 0.89, 0.89, 0.35, 0.37, 0.33, 0.47, 0.43, 0.38]
}

# Creating DataFrames for DF, DT, and WD
df = pd.DataFrame(data)

# Plotting DF, DT, and WD in individual subplots
fig, axs = plt.subplots(3, figsize=(10, 18))

# DF plot
axs[0].bar(df['SNo.'], df['DF'], color='b', alpha=0.6, label='DF Value')
axs[0].axhline(df['DF'].mean(), color='r', linestyle='dashed', linewidth=1, label='Mean DF')
axs[0].set_xlabel('Sample Number')
axs[0].set_ylabel('DF Value')
axs[0].set_title('DF Value of Steel Samples')
axs[0].legend()
axs[0].grid(True)
axs[0].set_xticks(df['SNo.'])

# DT plot
axs[1].bar(df['SNo.'], df['DT'], color='g', alpha=0.6, label='DT Value')
axs[1].axhline(df['DT'].mean(), color='r', linestyle='dashed', linewidth=1, label='Mean DT')
axs[1].set_xlabel('Sample Number')
axs[1].set_ylabel('DT Value')
axs[1].set_title('DT Value of Steel Samples')
axs[1].legend()
axs[1].grid(True)
axs[1].set_xticks(df['SNo.'])

# WD plot
axs[2].bar(df['SNo.'], df['WD'], color='m', alpha=0.6, label='WD Value')
axs[2].axhline(df['WD'].mean(), color='r', linestyle='dashed', linewidth=1, label='Mean WD')
axs[2].set_xlabel('Sample Number')
axs[2].set_ylabel('WD Value')
axs[2].set_title('WD Value of Steel Samples')
axs[2].legend()
axs[2].grid(True)
axs[2].set_xticks(df['SNo.'])

plt.tight_layout()
plt.show()
